# %%
import scanpy as sc

# %%
adata = sc.read('Norman_2019.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 111445 × 33694
# ...

# %%
adata.obs.describe(include='all').T
# Out:
#                    count unique                                     top  \
# guide_identity    111445    290  NegCtrl10_NegCtrl0__NegCtrl10_NegCtrl0
# read_count      111445.0    NaN                                     NaN
# UMI_count       111445.0    NaN                                     NaN
# coverage        111445.0    NaN                                     NaN
# gemgroup        111445.0    NaN                                     NaN
# ...                  ...    ...                                     ...
# guide_ZBTB10    111445.0    NaN                                     NaN
# guide_ZBTB25    111445.0    NaN                                     NaN
# guide_ZC3HAV1   111445.0    NaN                                     NaN
# guide_ZNF318    111445.0    NaN                                     NaN
# guide_ids         111445    237
#
#                  freq         mean         std  min        25%        50%  \
# ...
